# %% [markdown]
# Desenvolva um programa que recebe do usuário nome completo e ano de nascimento que seja entre 1922 e 2021.
# A partir dessas informações, o sistema mostrará o nome do usuário e a idade que completou, ou completará, no ano atual (2022).
#
# Caso o usuário não digite um número ou apareça um inválido no campo do ano, o sistema informará o erro e continuará perguntando até que um valor correto seja preenchido.

# %%
def idade_atual():
    while(True):
        nome = input("Digite seu nome: ")
        try:
            datanasc = int(input("Digite o ano em que você nasceu apenas se for entre 1922 e 2021(ex: 2000): "))
            if 1922 <= datanasc <= 2021:
                resultado = 2023 - datanasc
                print(f'Seu nome é {nome} e você possui {resultado} anos!')
                exit(0)
            else:
                print("Informe um valor válido!")
                idade_atual()
        except ValueError:
            print("Ocorreu um erro! Certifique-se de digitar um ano válido.")
            idade_atual()
idade_atual()
